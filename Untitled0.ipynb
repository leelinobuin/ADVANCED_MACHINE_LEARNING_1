# %%
print('hello')
# Out:
# hello

# %%
import numpy as np

# %%
pip install numpy

# %%
a = np.array([2,3,4]])
a
# Out:
#   File "<ipython-input-4-19f0e190336a>", line 1
#     a = np.array([2,3,4]])
#                         ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('
