# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
########## directory and file generate testing ##########
# file_content = "Hello, this is a text file."


# my_file_path = "/content/drive/My Drive/test-folder/example10.txt"

# if not os.path.isdir("/content/drive/My Drive/test-folder"):
#   os.mkdir("/content/drive/My Drive/test-folder")

# with open(my_file_path, "w") as file:
#     file.write(file_content)

# print("File saved to Google Drive!")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import os
import argparse
import random

from utils import progress_bar
import resnet18k
import mcnn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-eb557d83813f> in <cell line: 14>()
#      12 import random
#      13
# ---> 14 from utils import progress_bar
#      15 import resnet18k
#      16 import mcnn
#
# ModuleNotFoundError: No module named 'utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
arg_lr = 0.0001
arg_resume = False
arg_batch_size = 128
arg_model = "resnet18k"
arg_optimizer = "adam"
arg_noise = 0.0 #0.0, 0.1, 0.2
arg_data_size = 1.0
arg_data = "cifar10"
arg_w_param = 4 #1,2,4,8,16,32,64
arg_epoch = 1000

main_path = f'/content/drive/My Drive/ml-advanced-result'

# %%
main_path = f'/content/drive/My Drive/ml-advanced-result/{arg_noise}_{arg_w_param}'
#main_path = f'/content/drive/My Drive/ML_hw/{arg_model}_{arg_data}_{arg_optimizer}/noise-{arg_noise}_datasize-{arg_data_size}_w_param-{arg_w_param}'

device = 'cuda' if torch.cuda.is_available() else 'cpu'

best_acc = 0  # best test accuracy

start_epoch = 0  # start from epoch 0 or last checkpoint epoch

if arg_data == 'cifar10':
  num_classes = 10
elif arg_data == 'cifar100':
  num_classes = 100

# %%
def prepare_dataset():
    # Data
    print('==> Preparing data..')
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    if arg_data == 'cifar10':
        trainset = torchvision.datasets.CIFAR10(
            root='./data', train=True, download=True, transform=transform_train)
        new_len = int(arg_data_size*len(trainset))
        if arg_data_size < 1.0:
            trainset, _ = torch.utils.data.random_split(trainset, [new_len, len(trainset)-new_len])
        if arg_noise > 0.0:
            noise_len = int(len(trainset) * arg_noise)
            index = torch.randperm(len(trainset))[:noise_len]
            for i in index:
                noise_label = (trainset.targets[i] - 9)*(-1)
                trainset.targets[i] = noise_label

        trainloader = torch.utils.data.DataLoader(
            trainset, batch_size=arg_batch_size, shuffle=True, num_workers=2)

        testset = torchvision.datasets.CIFAR10(
            root='./data', train=False, download=True, transform=transform_test)
        testloader = torch.utils.data.DataLoader(
            testset, batch_size=100, shuffle=False, num_workers=2)

    elif arg_data == 'cifar100':
        trainset = torchvision.datasets.CIFAR100(
            root='./data', train=True, download=True, transform=transform_train)
        new_len = int(arg_data_size*len(trainset))
        if arg_data_size < 1.0:
            trainset, _ = torch.utils.data.random_split(trainset, [new_len, len(trainset)-new_len])
        if arg_noise > 0.0:
            noise_len = int(len(trainset) * arg_noise)
            index = torch.randperm(len(trainset))[:noise_len]
            for i in index:
                noise_label = (trainset.targets[i] - 9)*(-1)
                trainset.targets[i] = noise_label

        trainloader = torch.utils.data.DataLoader(
            trainset, batch_size=arg_batch_size, shuffle=True, num_workers=2)

        testset = torchvision.datasets.CIFAR100(
            root='./data', train=False, download=True, transform=transform_test)
        testloader = torch.utils.data.DataLoader(
            testset, batch_size=100, shuffle=False, num_workers=2)

    return trainloader, testloader

prepare_dataset()
# Out:
# ==> Preparing data..
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:01<00:00, 94694549.90it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# (<torch.utils.data.dataloader.DataLoader at 0x7c15750ebeb0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7c1499951f30>)

# %%
# Model
print('==> Building model..')
if arg_model == "resnet18k":
    net = resnet18k.make_resnet18k(k = arg_w_param, num_classes = num_classes)
    net = net.to(device)
elif arg_model == "mcnn":
    net = mcnn.make_cnn(c = arg_w_param, num_classes = num_classes)
    net = net.to(device)

if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True
# Out:
# ==> Building model..

# %%
if arg_resume==True:
    # Load checkpoint.
    print('==> Resuming from checkpoint..')
    assert os.path.isdir(os.path.join(main_path, 'checkpoint')), 'Error: no checkpoint directory found!'
    checkpoint = torch.load(os.path.join(main_path,'./checkpoint/ckpt.pth'))
    net.load_state_dict(checkpoint['net'])
    best_acc = checkpoint['acc']
    start_epoch = checkpoint['epoch']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c146800c0e7b> in <cell line: 1>()
# ----> 1 if arg_resume==True:
#       2     # Load checkpoint.
#       3     print('==> Resuming from checkpoint..')
#       4     assert os.path.isdir(os.path.join(main_path, 'checkpoint')), 'Error: no checkpoint directory found!'
#       5     checkpoint = torch.load(os.path.join(main_path,'./checkpoint/ckpt.pth'))
#
# NameError: name 'arg_resume' is not defined

# %%
criterion = nn.CrossEntropyLoss()
if arg_optimizer == "sgd":
    optimizer = optim.SGD(net.parameters(), lr=0.1, weight_decay=5e-4)
    epoch = arg_epoch
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
elif arg_optimizer == "adam":
    optimizer = optim.Adam(net.parameters(), lr=arg_lr)
    epoch = arg_epoch

# %%
train_loss_history = []
train_accuracy_history = []
test_loss_history = []
test_accuracy_history = []

os.makedirs(main_path, exist_ok=True)

# %%
# Training
def train(epoch):
    print('\nEpoch: %d' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()


        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        train_accuracy = 100.*correct/total

        progress_bar(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
                     % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))

    train_loss_history.append(train_loss) #여기
    train_accuracy_history.append(train_accuracy) #여기

# %%
def test(epoch):
    global best_acc
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
            test_accuracy = 100.*correct/total

            progress_bar(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
                         % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))
        test_loss_history.append(test_loss) #여기
        test_accuracy_history.append(test_accuracy) #여기

    # Save checkpoint.
    acc = 100.*correct/total
    print('Saving..')
    state = {
        'net': net.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir(os.path.join(main_path,'checkpoint')):
        os.mkdir(os.path.join(main_path,'checkpoint'))
    torch.save(state, os.path.join(main_path,'./checkpoint/ckpt.pth'))
    best_acc = acc

# %%
if __name__ == "__main__":
    trainloader, testloader = prepare_dataset()

    for epoch in range(start_epoch, start_epoch+epoch):
    #for epoch in range(100):
        train(epoch)
        test(epoch)
        if arg_optimizer=='sgd':
            scheduler.step()

        torch.save({
          'train_loss_history': train_loss_history,
          'train_accuracy_history': train_accuracy_history,
          'test_loss_history': test_loss_history,
          'test_accuracy_history': test_accuracy_history,
        }, os.path.join(main_path,f'history_{epoch}.pth'))
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
#  [================================================================>]  Step: 288ms | Tot: 32s204ms | Loss: 2.022 | Acc: 23.186% (11593/50000) 391/391
#  [================================================================>]  Step: 56ms | Tot: 4s434ms | Loss: 1.782 | Acc: 31.930% (3193/10000) 100/100
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 36ms | Tot: 30s264ms | Loss: 1.761 | Acc: 33.058% (16529/50000) 391/391
#  [================================================================>]  Step: 25ms | Tot: 3s965ms | Loss: 1.667 | Acc: 37.220% (3722/10000) 100/100
# Saving..
#
# Epoch: 2
#  [================================================================>]  Step: 26ms | Tot: 31s100ms | Loss: 1.681 | Acc: 36.620% (18310/50000) 391/391
#  [================================================================>]  Step: 29ms | Tot: 3s997ms | Loss: 1.608 | Acc: 38.880% (3888/10000) 100/100
# Saving..
#
# Epoch: 3
#  [================================================================>]  Step: 34ms | Tot: 30s458ms | Loss: 1.617 | Acc: 39.608% (19804/50000) 391/391
#  [================================================================>]  Step: 20ms | Tot: 5s80ms | Loss: 1.555 | Acc: 41.420% (4142/10000) 100/100
# Saving..
#
# Epoch: 4
#  [================================================================>]  Step: 54ms | Tot: 29s966ms | Loss: 1.577 | Acc: 41.446% (20723/50000) 391/391
#  [================================================================>]  Step: 16ms | Tot: 4s192ms | Loss: 1.526 | Acc: 43.000% (4300/10000) 100/100
# Saving..
#
# Epoch: 5
#  [================================================================>]  Step: 22ms | Tot: 30s258ms | Loss: 1.541 | Acc: 42.946% (21473/50000) 391/391
#  [================================================================>]  Step: 29ms | Tot: 4s | Loss: 1.493 | Acc: 44.430% (4443/10000) 100/100
# Saving..
#
# Epoch: 6
#  [================================================================>]  Step: 27ms | Tot: 30s607ms | Loss: 1.510 | Acc: 43.982% (21991/50000) 391/391
#  [================================================================>]  Step: 41ms | Tot: 4s853ms | Loss: 1.459 | Acc: 45.460% (4546/10000) 100/100
# Saving..
#
# Epoch: 7
#  [================================================================>]  Step: 37ms | Tot: 30s149ms | Loss: 1.481 | Acc: 45.416% (22708/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 4s381ms | Loss: 1.431 | Acc: 46.750% (4675/10000) 100/100
# Saving..
#
# Epoch: 8
#  [================================================================>]  Step: 27ms | Tot: 30s227ms | Loss: 1.461 | Acc: 46.422% (23211/50000) 391/391
#  [================================================================>]  Step: 16ms | Tot: 4s | Loss: 1.404 | Acc: 47.490% (4749/10000) 100/100
# Saving..
#
# Epoch: 9
#  [================================================================>]  Step: 24ms | Tot: 30s230ms | Loss: 1.432 | Acc: 47.356% (23678/50000) 391/391
#  [================================================================>]  Step: 16ms | Tot: 4s496ms | Loss: 1.388 | Acc: 48.580% (4858/10000) 100/100
# Saving..
#
# Epoch: 10
#  [================================================================>]  Step: 27ms | Tot: 30s116ms | Loss: 1.411 | Acc: 48.370% (24185/50000) 391/391
#  [================================================================>]  Step: 42ms | Tot: 4s836ms | Loss: 1.367 | Acc: 49.610% (4961/10000) 100/100
# Saving..
#
# Epoch: 11
#  [================================================================>]  Step: 24ms | Tot: 30s271ms | Loss: 1.384 | Acc: 49.398% (24699/50000) 391/391
#  [================================================================>]  Step: 15ms | Tot: 4s55ms | Loss: 1.343 | Acc: 50.190% (5019/10000) 100/100
# Saving..
#
# Epoch: 12
#  [================================================================>]  Step: 29ms | Tot: 30s493ms | Loss: 1.363 | Acc: 50.410% (25205/50000) 391/391
#  [================================================================>]  Step: 12ms | Tot: 4s391ms | Loss: 1.320 | Acc: 52.040% (5204/10000) 100/100
# Saving..
#
# Epoch: 13
#  [================================================================>]  Step: 32ms | Tot: 30s241ms | Loss: 1.350 | Acc: 50.958% (25479/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 5s105ms | Loss: 1.301 | Acc: 52.230% (5223/10000) 100/100
# Saving..
#
# Epoch: 14
#  [================================================================>]  Step: 34ms | Tot: 30s600ms | Loss: 1.330 | Acc: 51.870% (25935/50000) 391/391
#  [================================================================>]  Step: 16ms | Tot: 3s942ms | Loss: 1.297 | Acc: 52.300% (5230/10000) 100/100
# Saving..
#
# Epoch: 15
#  [================================================================>]  Step: 30ms | Tot: 30s415ms | Loss: 1.315 | Acc: 52.224% (26112/50000) 391/391
#  [================================================================>]  Step: 58ms | Tot: 4s173ms | Loss: 1.261 | Acc: 54.140% (5414/10000) 100/100
# Saving..
#
# Epoch: 16
#  [================================================================>]  Step: 32ms | Tot: 30s321ms | Loss: 1.293 | Acc: 53.150% (26575/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 5s306ms | Loss: 1.245 | Acc: 54.460% (5446/10000) 100/100
# Saving..
#
# Epoch: 17
#  [================================================================>]  Step: 24ms | Tot: 30s577ms | Loss: 1.276 | Acc: 53.890% (26945/50000) 391/391
#  [================================================================>]  Step: 33ms | Tot: 3s966ms | Loss: 1.231 | Acc: 55.170% (5517/10000) 100/100
# Saving..
#
# Epoch: 18
#  [================================================================>]  Step: 27ms | Tot: 30s413ms | Loss: 1.264 | Acc: 54.434% (27217/50000) 391/391
#  [================================================================>]  Step: 11ms | Tot: 4s102ms | Loss: 1.220 | Acc: 55.500% (5550/10000) 100/100
# Saving..
#
# Epoch: 19
#  [================================================================>]  Step: 25ms | Tot: 30s467ms | Loss: 1.246 | Acc: 54.944% (27472/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 5s157ms | Loss: 1.200 | Acc: 56.330% (5633/10000) 100/100
# Saving..
#
# Epoch: 20
#  [================================================================>]  Step: 19ms | Tot: 30s661ms | Loss: 1.236 | Acc: 55.148% (27574/50000) 391/391
#  [================================================================>]  Step: 20ms | Tot: 3s936ms | Loss: 1.193 | Acc: 56.420% (5642/10000) 100/100
# Saving..
#
# Epoch: 21
#  [================================================================>]  Step: 25ms | Tot: 30s353ms | Loss: 1.223 | Acc: 56.146% (28073/50000) 391/391
#  [================================================================>]  Step: 26ms | Tot: 3s952ms | Loss: 1.175 | Acc: 56.960% (5696/10000) 100/100
# Saving..
#
# Epoch: 22
#  [================================================================>]  Step: 30ms | Tot: 30s419ms | Loss: 1.206 | Acc: 56.742% (28371/50000) 391/391
#  [================================================================>]  Step: 26ms | Tot: 5s692ms | Loss: 1.167 | Acc: 57.340% (5734/10000) 100/100
# Saving..
#
# Epoch: 23
#  [================================================================>]  Step: 30ms | Tot: 30s32ms | Loss: 1.196 | Acc: 57.150% (28575/50000) 391/391
#  [================================================================>]  Step: 23ms | Tot: 3s908ms | Loss: 1.168 | Acc: 57.400% (5740/10000) 100/100
# Saving..
#
# Epoch: 24
#  [================================================================>]  Step: 22ms | Tot: 30s189ms | Loss: 1.184 | Acc: 57.408% (28704/50000) 391/391
#  [================================================================>]  Step: 16ms | Tot: 3s949ms | Loss: 1.149 | Acc: 58.180% (5818/10000) 100/100
# Saving..
#
# Epoch: 25
#  [================================================================>]  Step: 25ms | Tot: 29s979ms | Loss: 1.167 | Acc: 58.116% (29058/50000) 391/391
#  [================================================================>]  Step: 32ms | Tot: 5s58ms | Loss: 1.137 | Acc: 58.450% (5845/10000) 100/100
# Saving..
#
# Epoch: 26
#  [================================================================>]  Step: 36ms | Tot: 29s908ms | Loss: 1.161 | Acc: 58.490% (29245/50000) 391/391
#  [================================================================>]  Step: 15ms | Tot: 3s929ms | Loss: 1.127 | Acc: 59.420% (5942/10000) 100/100
# Saving..
#
# Epoch: 27
#  [================================================================>]  Step: 22ms | Tot: 30s36ms | Loss: 1.154 | Acc: 58.376% (29188/50000) 391/391
#  [================================================================>]  Step: 29ms | Tot: 4s53ms | Loss: 1.126 | Acc: 59.030% (5903/10000) 100/100
# Saving..
#
# Epoch: 28
#  [================================================================>]  Step: 24ms | Tot: 29s940ms | Loss: 1.139 | Acc: 59.118% (29559/50000) 391/391
#  [================================================================>]  Step: 34ms | Tot: 5s9ms | Loss: 1.110 | Acc: 59.780% (5978/10000) 100/100
# Saving..
#
# Epoch: 29
#  [================================================================>]  Step: 22ms | Tot: 29s324ms | Loss: 1.134 | Acc: 59.448% (29724/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 3s855ms | Loss: 1.113 | Acc: 59.840% (5984/10000) 100/100
# Saving..
#
# Epoch: 30
#  [================================================================>]  Step: 27ms | Tot: 29s362ms | Loss: 1.123 | Acc: 59.926% (29963/50000) 391/391
#  [================================================================>]  Step: 17ms | Tot: 3s948ms | Loss: 1.098 | Acc: 60.530% (6053/10000) 100/100
# Saving..
#
# Epoch: 31
#  [================================================================>]  Step: 58ms | Tot: 29s6ms | Loss: 1.111 | Acc: 60.284% (30142/50000) 391/391
#  [================================================================>]  Step: 14ms | Tot: 4s713ms | Loss: 1.089 | Acc: 60.890% (6089/10000) 100/100
# Saving..
#
# Epoch: 32
#  [================================================================>]  Step: 24ms | Tot: 29s229ms | Loss: 1.106 | Acc: 60.496% (30248/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 3s859ms | Loss: 1.085 | Acc: 60.940% (6094/10000) 100/100
# Saving..
#
# Epoch: 33
#  [================================================================>]  Step: 34ms | Tot: 29s335ms | Loss: 1.090 | Acc: 61.026% (30513/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 4s339ms | Loss: 1.070 | Acc: 61.450% (6145/10000) 100/100
# Saving..
#
# Epoch: 34
#  [================================================================>]  Step: 34ms | Tot: 29s227ms | Loss: 1.081 | Acc: 61.316% (30658/50000) 391/391
#  [================================================================>]  Step: 50ms | Tot: 4s335ms | Loss: 1.055 | Acc: 61.600% (6160/10000) 100/100
# Saving..
#
# Epoch: 35
#  [================================================================>]  Step: 23ms | Tot: 29s310ms | Loss: 1.078 | Acc: 61.488% (30744/50000) 391/391
#  [================================================================>]  Step: 22ms | Tot: 3s853ms | Loss: 1.061 | Acc: 61.580% (6158/10000) 100/100
# Saving..
#
# Epoch: 36
#  [================================================================>]  Step: 28ms | Tot: 29s316ms | Loss: 1.063 | Acc: 61.956% (30978/50000) 391/391
#  [================================================================>]  Step: 62ms | Tot: 4s324ms | Loss: 1.041 | Acc: 62.410% (6241/10000) 100/100
# Saving..
#
# Epoch: 37
#  [================================================================>]  Step: 35ms | Tot: 29s53ms | Loss: 1.056 | Acc: 62.274% (31137/50000) 391/391
#  [================================================================>]  Step: 42ms | Tot: 4s668ms | Loss: 1.041 | Acc: 62.570% (6257/10000) 100/100
# Saving..
#
# Epoch: 38
#  [================================================================>]  Step: 33ms | Tot: 30s32ms | Loss: 1.050 | Acc: 62.394% (31197/50000) 391/391
#  [================================================================>]  Step: 21ms | Tot: 3s988ms | Loss: 1.023 | Acc: 63.220% (6322/10000) 100/100
# Saving..
#
# Epoch: 39
#  [================================================================>]  Step: 33ms | Tot: 30s186ms | Loss: 1.044 | Acc: 62.706% (31353/50000) 391/391
#  [================================================================>]  Step: 52ms | Tot: 4s556ms | Loss: 1.024 | Acc: 63.240% (6324/10000) 100/100
# Saving..
#
# Epoch: 40
#  [================================================================>]  Step: 25ms | Tot: 30s242ms | Loss: 1.034 | Acc: 62.882% (31441/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 4s514ms | Loss: 1.024 | Acc: 63.160% (6316/10000) 100/100
# Saving..
#
# Epoch: 41
#  [================================================================>]  Step: 32ms | Tot: 30s295ms | Loss: 1.029 | Acc: 63.528% (31764/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 4s30ms | Loss: 1.010 | Acc: 63.530% (6353/10000) 100/100
# Saving..
#
# Epoch: 42
#  [================================================================>]  Step: 32ms | Tot: 30s76ms | Loss: 1.026 | Acc: 63.388% (31694/50000) 391/391
#  [================================================================>]  Step: 23ms | Tot: 4s992ms | Loss: 1.003 | Acc: 64.120% (6412/10000) 100/100
# Saving..
#
# Epoch: 43
#  [================================================================>]  Step: 27ms | Tot: 30s197ms | Loss: 1.017 | Acc: 63.830% (31915/50000) 391/391
#  [================================================================>]  Step: 27ms | Tot: 4s76ms | Loss: 1.011 | Acc: 63.780% (6378/10000) 100/100
# Saving..
#
# Epoch: 44
#  [================================================================>]  Step: 30ms | Tot: 30s141ms | Loss: 1.010 | Acc: 64.032% (32016/50000) 391/391
#  [================================================================>]  Step: 22ms | Tot: 3s938ms | Loss: 0.996 | Acc: 64.310% (6431/10000) 100/100
# Saving..
#
# Epoch: 45
#  [================================================================>]  Step: 27ms | Tot: 30s180ms | Loss: 0.999 | Acc: 64.226% (32113/50000) 391/391
#  [================================================================>]  Step: 45ms | Tot: 5s617ms | Loss: 0.997 | Acc: 64.650% (6465/10000) 100/100
# Saving..
#
# Epoch: 46
#  [================================================================>]  Step: 21ms | Tot: 30s337ms | Loss: 0.995 | Acc: 64.404% (32202/50000) 391/391
#  [================================================================>]  Step: 25ms | Tot: 4s73ms | Loss: 0.987 | Acc: 64.660% (6466/10000) 100/100
# Saving..
#
# Epoch: 47
#  [================================================================>]  Step: 31ms | Tot: 30s176ms | Loss: 0.989 | Acc: 64.756% (32378/50000) 391/391
#  [================================================================>]  Step: 27ms | Tot: 4s87ms | Loss: 0.980 | Acc: 65.150% (6515/10000) 100/100
# Saving..
#
# Epoch: 48
#  [================================================================>]  Step: 41ms | Tot: 30s92ms | Loss: 0.986 | Acc: 64.912% (32456/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 5s144ms | Loss: 0.971 | Acc: 65.410% (6541/10000) 100/100
# Saving..
#
# Epoch: 49
#  [================================================================>]  Step: 24ms | Tot: 30s87ms | Loss: 0.975 | Acc: 65.308% (32654/50000) 391/391
#  [================================================================>]  Step: 29ms | Tot: 3s994ms | Loss: 0.969 | Acc: 65.330% (6533/10000) 100/100
# Saving..
#
# Epoch: 50
#  [================================================================>]  Step: 32ms | Tot: 30s189ms | Loss: 0.977 | Acc: 65.260% (32630/50000) 391/391
#  [================================================================>]  Step: 33ms | Tot: 4s279ms | Loss: 0.965 | Acc: 65.900% (6590/10000) 100/100
# Saving..
#
# Epoch: 51
#  [================================================================>]  Step: 34ms | Tot: 30s390ms | Loss: 0.967 | Acc: 65.538% (32769/50000) 391/391
#  [================================================================>]  Step: 20ms | Tot: 4s733ms | Loss: 0.965 | Acc: 66.020% (6602/10000) 100/100
# Saving..
#
# Epoch: 52
#  [================================================================>]  Step: 32ms | Tot: 30s454ms | Loss: 0.965 | Acc: 65.614% (32807/50000) 391/391
#  [================================================================>]  Step: 40ms | Tot: 4s27ms | Loss: 0.967 | Acc: 65.630% (6563/10000) 100/100
# Saving..
#
# Epoch: 53
#  [================================================================>]  Step: 32ms | Tot: 30s213ms | Loss: 0.957 | Acc: 65.984% (32992/50000) 391/391
#  [================================================================>]  Step: 29ms | Tot: 4s821ms | Loss: 0.952 | Acc: 66.060% (6606/10000) 100/100
# Saving..
#
# Epoch: 54
#  [================================================================>]  Step: 35ms | Tot: 30s403ms | Loss: 0.954 | Acc: 66.084% (33042/50000) 391/391
#  [================================================================>]  Step: 37ms | Tot: 4s551ms | Loss: 0.944 | Acc: 66.540% (6654/10000) 100/100
# Saving..
#
# Epoch: 55
#  [================================================================>]  Step: 28ms | Tot: 30s272ms | Loss: 0.947 | Acc: 66.420% (33210/50000) 391/391
#  [================================================================>]  Step: 41ms | Tot: 3s967ms | Loss: 0.946 | Acc: 66.190% (6619/10000) 100/100
# Saving..
#
# Epoch: 56
#  [================================================================>]  Step: 25ms | Tot: 30s344ms | Loss: 0.942 | Acc: 66.538% (33269/50000) 391/391
#  [================================================================>]  Step: 47ms | Tot: 5s416ms | Loss: 0.943 | Acc: 66.600% (6660/10000) 100/100
# Saving..
#
# Epoch: 57
#  [================================================================>]  Step: 29ms | Tot: 30s161ms | Loss: 0.933 | Acc: 66.790% (33395/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 3s993ms | Loss: 0.942 | Acc: 66.660% (6666/10000) 100/100
# Saving..
#
# Epoch: 58
#  [================================================================>]  Step: 23ms | Tot: 30s248ms | Loss: 0.934 | Acc: 66.922% (33461/50000) 391/391
#  [================================================================>]  Step: 27ms | Tot: 4s60ms | Loss: 0.929 | Acc: 66.890% (6689/10000) 100/100
# Saving..
#
# Epoch: 59
#  [================================================================>]  Step: 25ms | Tot: 30s492ms | Loss: 0.927 | Acc: 66.930% (33465/50000) 391/391
#  [================================================================>]  Step: 27ms | Tot: 5s216ms | Loss: 0.923 | Acc: 67.160% (6716/10000) 100/100
# Saving..
#
# Epoch: 60
#  [================================================================>]  Step: 25ms | Tot: 30s224ms | Loss: 0.924 | Acc: 67.150% (33575/50000) 391/391
#  [================================================================>]  Step: 26ms | Tot: 4s82ms | Loss: 0.920 | Acc: 67.440% (6744/10000) 100/100
# Saving..
#
# Epoch: 61
#  [================================================================>]  Step: 35ms | Tot: 30s262ms | Loss: 0.921 | Acc: 67.284% (33642/50000) 391/391
#  [================================================================>]  Step: 59ms | Tot: 4s579ms | Loss: 0.908 | Acc: 67.800% (6780/10000) 100/100
# Saving..
#
# Epoch: 62
#  [================================================================>]  Step: 46ms | Tot: 30s322ms | Loss: 0.912 | Acc: 67.522% (33761/50000) 391/391
#  [================================================================>]  Step: 21ms | Tot: 4s545ms | Loss: 0.912 | Acc: 67.780% (6778/10000) 100/100
# Saving..
#
# Epoch: 63
#  [================================================================>]  Step: 27ms | Tot: 30s189ms | Loss: 0.908 | Acc: 67.902% (33951/50000) 391/391
#  [================================================================>]  Step: 38ms | Tot: 4s | Loss: 0.915 | Acc: 67.610% (6761/10000) 100/100
# Saving..
#
# Epoch: 64
#  [================================================================>]  Step: 27ms | Tot: 30s570ms | Loss: 0.904 | Acc: 67.888% (33944/50000) 391/391
#  [================================================================>]  Step: 17ms | Tot: 4s836ms | Loss: 0.902 | Acc: 68.400% (6840/10000) 100/100
# Saving..
#
# Epoch: 65
#  [================================================================>]  Step: 42ms | Tot: 30s172ms | Loss: 0.904 | Acc: 67.952% (33976/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 4s96ms | Loss: 0.904 | Acc: 68.130% (6813/10000) 100/100
# Saving..
#
# Epoch: 66
#  [================================================================>]  Step: 27ms | Tot: 30s287ms | Loss: 0.894 | Acc: 68.058% (34029/50000) 391/391
#  [================================================================>]  Step: 40ms | Tot: 4s102ms | Loss: 0.898 | Acc: 68.540% (6854/10000) 100/100
# Saving..
#
# Epoch: 67
#  [================================================================>]  Step: 27ms | Tot: 30s401ms | Loss: 0.898 | Acc: 68.136% (34068/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 5s319ms | Loss: 0.893 | Acc: 68.540% (6854/10000) 100/100
# Saving..
#
# Epoch: 68
#  [================================================================>]  Step: 30ms | Tot: 30s580ms | Loss: 0.887 | Acc: 68.630% (34315/50000) 391/391
#  [================================================================>]  Step: 36ms | Tot: 4s110ms | Loss: 0.892 | Acc: 68.340% (6834/10000) 100/100
# Saving..
#
# Epoch: 69
#  [================================================================>]  Step: 34ms | Tot: 30s637ms | Loss: 0.885 | Acc: 68.578% (34289/50000) 391/391
#  [================================================================>]  Step: 25ms | Tot: 4s140ms | Loss: 0.884 | Acc: 68.820% (6882/10000) 100/100
# Saving..
#
# Epoch: 70
#  [================================================================>]  Step: 35ms | Tot: 30s971ms | Loss: 0.881 | Acc: 68.754% (34377/50000) 391/391
#  [================================================================>]  Step: 14ms | Tot: 5s135ms | Loss: 0.886 | Acc: 68.920% (6892/10000) 100/100
# Saving..
#
# Epoch: 71
#  [================================================================>]  Step: 18ms | Tot: 30s786ms | Loss: 0.880 | Acc: 68.898% (34449/50000) 391/391
#  [================================================================>]  Step: 35ms | Tot: 4s131ms | Loss: 0.885 | Acc: 69.110% (6911/10000) 100/100
# Saving..
#
# Epoch: 72
#  [================================================================>]  Step: 27ms | Tot: 30s945ms | Loss: 0.870 | Acc: 69.122% (34561/50000) 391/391
#  [================================================================>]  Step: 24ms | Tot: 5s162ms | Loss: 0.876 | Acc: 69.370% (6937/10000) 100/100
# Saving..
#
# Epoch: 73
#  [================================================================>]  Step: 40ms | Tot: 30s475ms | Loss: 0.870 | Acc: 68.908% (34454/50000) 391/391
#  [================================================================>]  Step: 53ms | Tot: 4s276ms | Loss: 0.874 | Acc: 69.020% (6902/10000) 100/100
# Saving..
#
# Epoch: 74
#  [================================================================>]  Step: 32ms | Tot: 30s789ms | Loss: 0.869 | Acc: 69.190% (34595/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 4s124ms | Loss: 0.865 | Acc: 69.370% (6937/10000) 100/100
# Saving..
#
# Epoch: 75
#  [================================================================>]  Step: 57ms | Tot: 31s269ms | Loss: 0.868 | Acc: 69.096% (34548/50000) 391/391
#  [================================================================>]  Step: 23ms | Tot: 5s168ms | Loss: 0.862 | Acc: 69.720% (6972/10000) 100/100
# Saving..
#
# Epoch: 76
#  [================================================================>]  Step: 27ms | Tot: 30s829ms | Loss: 0.858 | Acc: 69.580% (34790/50000) 391/391
#  [================================================================>]  Step: 20ms | Tot: 4s164ms | Loss: 0.869 | Acc: 69.450% (6945/10000) 100/100
# Saving..
#
# Epoch: 77
#  [================================================================>]  Step: 22ms | Tot: 30s672ms | Loss: 0.858 | Acc: 69.686% (34843/50000) 391/391
#  [================================================================>]  Step: 45ms | Tot: 4s982ms | Loss: 0.869 | Acc: 69.490% (6949/10000) 100/100
# Saving..
#
# Epoch: 78
#  [================================================================>]  Step: 36ms | Tot: 30s909ms | Loss: 0.861 | Acc: 69.626% (34813/50000) 391/391
#  [================================================================>]  Step: 26ms | Tot: 4s339ms | Loss: 0.858 | Acc: 69.730% (6973/10000) 100/100
# Saving..
#
# Epoch: 79
#  [================================================================>]  Step: 27ms | Tot: 30s604ms | Loss: 0.851 | Acc: 69.926% (34963/50000) 391/391
#  [================================================================>]  Step: 32ms | Tot: 4s110ms | Loss: 0.851 | Acc: 69.730% (6973/10000) 100/100
# Saving..
#
# Epoch: 80
#  [================================================================>]  Step: 33ms | Tot: 30s628ms | Loss: 0.847 | Acc: 70.030% (35015/50000) 391/391
#  [================================================================>]  Step: 35ms | Tot: 5s404ms | Loss: 0.854 | Acc: 69.550% (6955/10000) 100/100
# Saving..
#
# Epoch: 81
#  [================================================================>]  Step: 27ms | Tot: 30s409ms | Loss: 0.846 | Acc: 70.084% (35042/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 4s137ms | Loss: 0.852 | Acc: 69.800% (6980/10000) 100/100
# Saving..
#
# Epoch: 82
#  [================================================================>]  Step: 26ms | Tot: 30s764ms | Loss: 0.840 | Acc: 70.154% (35077/50000) 391/391
#  [================================================================>]  Step: 32ms | Tot: 4s383ms | Loss: 0.848 | Acc: 70.020% (7002/10000) 100/100
# Saving..
#
# Epoch: 83
#  [================================================================>]  Step: 38ms | Tot: 30s802ms | Loss: 0.838 | Acc: 70.270% (35135/50000) 391/391
#  [================================================================>]  Step: 20ms | Tot: 4s836ms | Loss: 0.849 | Acc: 70.040% (7004/10000) 100/100
# Saving..
#
# Epoch: 84
#  [================================================================>]  Step: 29ms | Tot: 30s558ms | Loss: 0.835 | Acc: 70.556% (35278/50000) 391/391
#  [================================================================>]  Step: 38ms | Tot: 3s998ms | Loss: 0.844 | Acc: 70.080% (7008/10000) 100/100
# Saving..
#
# Epoch: 85
#  [================================================================>]  Step: 27ms | Tot: 30s525ms | Loss: 0.833 | Acc: 70.600% (35300/50000) 391/391
#  [================================================================>]  Step: 49ms | Tot: 4s987ms | Loss: 0.851 | Acc: 70.010% (7001/10000) 100/100
# Saving..
#
# Epoch: 86
#  [================================================================>]  Step: 35ms | Tot: 30s382ms | Loss: 0.833 | Acc: 70.588% (35294/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 4s145ms | Loss: 0.835 | Acc: 70.570% (7057/10000) 100/100
# Saving..
#
# Epoch: 87
#  [================================================================>]  Step: 26ms | Tot: 30s340ms | Loss: 0.826 | Acc: 70.894% (35447/50000) 391/391
#  [================================================================>]  Step: 22ms | Tot: 4s133ms | Loss: 0.834 | Acc: 70.470% (7047/10000) 100/100
# Saving..
#
# Epoch: 88
#  [================================================================>]  Step: 28ms | Tot: 30s223ms | Loss: 0.825 | Acc: 70.994% (35497/50000) 391/391
#  [================================================================>]  Step: 14ms | Tot: 5s358ms | Loss: 0.838 | Acc: 70.340% (7034/10000) 100/100
# Saving..
#
# Epoch: 89
#  [================================================================>]  Step: 25ms | Tot: 30s113ms | Loss: 0.822 | Acc: 70.990% (35495/50000) 391/391
#  [================================================================>]  Step: 33ms | Tot: 3s883ms | Loss: 0.836 | Acc: 70.740% (7074/10000) 100/100
# Saving..
#
# Epoch: 90
#  [================================================================>]  Step: 26ms | Tot: 29s444ms | Loss: 0.821 | Acc: 70.868% (35434/50000) 391/391
#  [================================================================>]  Step: 17ms | Tot: 3s864ms | Loss: 0.832 | Acc: 70.610% (7061/10000) 100/100
# Saving..
#
# Epoch: 91
#  [================================================================>]  Step: 27ms | Tot: 29s682ms | Loss: 0.815 | Acc: 71.456% (35728/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 5s377ms | Loss: 0.831 | Acc: 70.770% (7077/10000) 100/100
# Saving..
#
# Epoch: 92
#  [================================================================>]  Step: 28ms | Tot: 29s621ms | Loss: 0.808 | Acc: 71.434% (35717/50000) 391/391
#  [================================================================>]  Step: 33ms | Tot: 3s850ms | Loss: 0.828 | Acc: 70.880% (7088/10000) 100/100
# Saving..
#
# Epoch: 93
#  [================================================================>]  Step: 25ms | Tot: 29s874ms | Loss: 0.811 | Acc: 71.374% (35687/50000) 391/391
#  [================================================================>]  Step: 25ms | Tot: 4s65ms | Loss: 0.830 | Acc: 70.810% (7081/10000) 100/100
# Saving..
#
# Epoch: 94
#  [================================================================>]  Step: 22ms | Tot: 29s244ms | Loss: 0.804 | Acc: 71.592% (35796/50000) 391/391
#  [================================================================>]  Step: 34ms | Tot: 5s462ms | Loss: 0.824 | Acc: 70.830% (7083/10000) 100/100
# Saving..
#
# Epoch: 95
#  [================================================================>]  Step: 24ms | Tot: 29s572ms | Loss: 0.803 | Acc: 71.728% (35864/50000) 391/391
#  [================================================================>]  Step: 21ms | Tot: 3s864ms | Loss: 0.817 | Acc: 71.080% (7108/10000) 100/100
# Saving..
#
# Epoch: 96
#  [================================================================>]  Step: 31ms | Tot: 29s388ms | Loss: 0.804 | Acc: 71.548% (35774/50000) 391/391
#  [================================================================>]  Step: 46ms | Tot: 3s923ms | Loss: 0.818 | Acc: 71.480% (7148/10000) 100/100
# Saving..
#
# Epoch: 97
#  [================================================================>]  Step: 20ms | Tot: 29s682ms | Loss: 0.799 | Acc: 71.598% (35799/50000) 391/391
#  [================================================================>]  Step: 69ms | Tot: 5s243ms | Loss: 0.818 | Acc: 71.230% (7123/10000) 100/100
# Saving..
#
# Epoch: 98
#  [================================================================>]  Step: 35ms | Tot: 29s496ms | Loss: 0.796 | Acc: 72.040% (36020/50000) 391/391
#  [================================================================>]  Step: 40ms | Tot: 3s835ms | Loss: 0.812 | Acc: 71.390% (7139/10000) 100/100
# Saving..
#
# Epoch: 99
#  [================================================================>]  Step: 24ms | Tot: 29s601ms | Loss: 0.790 | Acc: 72.182% (36091/50000) 391/391
#  [================================================================>]  Step: 21ms | Tot: 3s896ms | Loss: 0.814 | Acc: 71.350% (7135/10000) 100/100
# Saving..
#
# Epoch: 100
#  [================================================================>]  Step: 25ms | Tot: 29s558ms | Loss: 0.791 | Acc: 72.048% (36024/50000) 391/391
#  [================================================================>]  Step: 37ms | Tot: 5s194ms | Loss: 0.812 | Acc: 71.530% (7153/10000) 100/100
# Saving..
#
# Epoch: 101
#  [================================================================>]  Step: 27ms | Tot: 29s664ms | Loss: 0.788 | Acc: 71.986% (35993/50000) 391/391
#  [================================================================>]  Step: 37ms | Tot: 3s936ms | Loss: 0.812 | Acc: 71.580% (7158/10000) 100/100
# Saving..
#
# Epoch: 102
#  [================================================================>]  Step: 34ms | Tot: 29s554ms | Loss: 0.789 | Acc: 72.032% (36016/50000) 391/391
#  [================================================================>]  Step: 6ms | Tot: 3s755ms | Loss: 0.805 | Acc: 71.720% (7172/10000) 100/100
# Saving..
#
# Epoch: 103
#  [================================================================>]  Step: 34ms | Tot: 29s783ms | Loss: 0.783 | Acc: 72.250% (36125/50000) 391/391
#  [================================================================>]  Step: 62ms | Tot: 5s545ms | Loss: 0.816 | Acc: 71.710% (7171/10000) 100/100
# Saving..
#
# Epoch: 104
#  [================================================================>]  Step: 23ms | Tot: 29s992ms | Loss: 0.781 | Acc: 72.542% (36271/50000) 391/391
#  [================================================================>]  Step: 16ms | Tot: 3s852ms | Loss: 0.797 | Acc: 72.340% (7234/10000) 100/100
# Saving..
#
# Epoch: 105
#  [================================================================>]  Step: 33ms | Tot: 29s863ms | Loss: 0.780 | Acc: 72.476% (36238/50000) 391/391
#  [================================================================>]  Step: 29ms | Tot: 3s870ms | Loss: 0.802 | Acc: 72.330% (7233/10000) 100/100
# Saving..
#
# Epoch: 106
#  [================================================================>]  Step: 25ms | Tot: 30s185ms | Loss: 0.778 | Acc: 72.418% (36209/50000) 391/391
#  [================================================================>]  Step: 45ms | Tot: 5s101ms | Loss: 0.798 | Acc: 71.930% (7193/10000) 100/100
# Saving..
#
# Epoch: 107
#  [================================================================>]  Step: 29ms | Tot: 29s749ms | Loss: 0.782 | Acc: 72.360% (36180/50000) 391/391
#  [================================================================>]  Step: 32ms | Tot: 3s932ms | Loss: 0.794 | Acc: 72.170% (7217/10000) 100/100
# Saving..
#
# Epoch: 108
#  [================================================================>]  Step: 20ms | Tot: 29s820ms | Loss: 0.774 | Acc: 72.686% (36343/50000) 391/391
#  [================================================================>]  Step: 11ms | Tot: 4s368ms | Loss: 0.793 | Acc: 72.410% (7241/10000) 100/100
# Saving..
#
# Epoch: 109
#  [================================================================>]  Step: 34ms | Tot: 30s176ms | Loss: 0.778 | Acc: 72.448% (36224/50000) 391/391
#  [================================================================>]  Step: 30ms | Tot: 4s163ms | Loss: 0.791 | Acc: 72.180% (7218/10000) 100/100
# Saving..
#
# Epoch: 110
#  [================================================================>]  Step: 24ms | Tot: 29s442ms | Loss: 0.768 | Acc: 72.990% (36495/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 3s876ms | Loss: 0.790 | Acc: 72.620% (7262/10000) 100/100
# Saving..
#
# Epoch: 111
#  [================================================================>]  Step: 29ms | Tot: 29s520ms | Loss: 0.765 | Acc: 73.030% (36515/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 5s13ms | Loss: 0.788 | Acc: 72.520% (7252/10000) 100/100
# Saving..
#
# Epoch: 112
#  [================================================================>]  Step: 28ms | Tot: 28s894ms | Loss: 0.761 | Acc: 73.258% (36629/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 3s855ms | Loss: 0.789 | Acc: 72.520% (7252/10000) 100/100
# Saving..
#
# Epoch: 113
#  [================================================================>]  Step: 29ms | Tot: 29s913ms | Loss: 0.766 | Acc: 72.898% (36449/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 4s16ms | Loss: 0.792 | Acc: 72.430% (7243/10000) 100/100
# Saving..
#
# Epoch: 114
#  [================================================================>]  Step: 25ms | Tot: 30s11ms | Loss: 0.760 | Acc: 73.202% (36601/50000) 391/391
#  [================================================================>]  Step: 46ms | Tot: 5s257ms | Loss: 0.780 | Acc: 72.730% (7273/10000) 100/100
# Saving..
#
# Epoch: 115
#  [================================================================>]  Step: 34ms | Tot: 29s774ms | Loss: 0.758 | Acc: 73.478% (36739/50000) 391/391
#  [================================================================>]  Step: 16ms | Tot: 3s907ms | Loss: 0.781 | Acc: 72.620% (7262/10000) 100/100
# Saving..
#
# Epoch: 116
#  [================================================================>]  Step: 16ms | Tot: 29s469ms | Loss: 0.759 | Acc: 73.206% (36603/50000) 391/391
#  [================================================================>]  Step: 27ms | Tot: 3s919ms | Loss: 0.788 | Acc: 72.810% (7281/10000) 100/100
# Saving..
#
# Epoch: 117
#  [================================================================>]  Step: 26ms | Tot: 29s508ms | Loss: 0.760 | Acc: 73.116% (36558/50000) 391/391
#  [================================================================>]  Step: 52ms | Tot: 4s823ms | Loss: 0.783 | Acc: 73.060% (7306/10000) 100/100
# Saving..
#
# Epoch: 118
#  [================================================================>]  Step: 29ms | Tot: 29s792ms | Loss: 0.752 | Acc: 73.510% (36755/50000) 391/391
#  [================================================================>]  Step: 32ms | Tot: 4s391ms | Loss: 0.774 | Acc: 73.100% (7310/10000) 100/100
# Saving..
#
# Epoch: 119
#  [================================================================>]  Step: 21ms | Tot: 30s834ms | Loss: 0.752 | Acc: 73.676% (36838/50000) 391/391
#  [================================================================>]  Step: 21ms | Tot: 4s172ms | Loss: 0.774 | Acc: 73.070% (7307/10000) 100/100
# Saving..
#
# Epoch: 120
#  [================================================================>]  Step: 28ms | Tot: 30s998ms | Loss: 0.748 | Acc: 73.622% (36811/50000) 391/391
#  [================================================================>]  Step: 58ms | Tot: 5s368ms | Loss: 0.779 | Acc: 72.880% (7288/10000) 100/100
# Saving..
#
# Epoch: 121
#  [================================================================>]  Step: 75ms | Tot: 30s819ms | Loss: 0.749 | Acc: 73.526% (36763/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 4s211ms | Loss: 0.776 | Acc: 73.090% (7309/10000) 100/100
# Saving..
#
# Epoch: 122
#  [================================================================>]  Step: 26ms | Tot: 30s627ms | Loss: 0.748 | Acc: 73.726% (36863/50000) 391/391
#  [================================================================>]  Step: 22ms | Tot: 4s125ms | Loss: 0.774 | Acc: 73.350% (7335/10000) 100/100
# Saving..
#
# Epoch: 123
#  [================================================================>]  Step: 29ms | Tot: 30s644ms | Loss: 0.742 | Acc: 73.776% (36888/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 5s659ms | Loss: 0.781 | Acc: 73.100% (7310/10000) 100/100
# Saving..
#
# Epoch: 124
#  [================================================================>]  Step: 27ms | Tot: 31s146ms | Loss: 0.741 | Acc: 73.974% (36987/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 4s241ms | Loss: 0.774 | Acc: 73.480% (7348/10000) 100/100
# Saving..
#
# Epoch: 125
#  [================================================================>]  Step: 28ms | Tot: 31s69ms | Loss: 0.741 | Acc: 73.770% (36885/50000) 391/391
#  [================================================================>]  Step: 14ms | Tot: 4s362ms | Loss: 0.767 | Acc: 73.170% (7317/10000) 100/100
# Saving..
#
# Epoch: 126
#  [================================================================>]  Step: 59ms | Tot: 30s771ms | Loss: 0.740 | Acc: 73.962% (36981/50000) 391/391
#  [================================================================>]  Step: 33ms | Tot: 5s143ms | Loss: 0.773 | Acc: 73.330% (7333/10000) 100/100
# Saving..
#
# Epoch: 127
#  [================================================================>]  Step: 27ms | Tot: 30s563ms | Loss: 0.736 | Acc: 74.048% (37024/50000) 391/391
#  [================================================================>]  Step: 20ms | Tot: 4s72ms | Loss: 0.759 | Acc: 73.770% (7377/10000) 100/100
# Saving..
#
# Epoch: 128
#  [================================================================>]  Step: 24ms | Tot: 30s226ms | Loss: 0.736 | Acc: 74.190% (37095/50000) 391/391
#  [================================================================>]  Step: 31ms | Tot: 4s829ms | Loss: 0.771 | Acc: 72.890% (7289/10000) 100/100
# Saving..
#
# Epoch: 129
#  [================================================================>]  Step: 25ms | Tot: 30s577ms | Loss: 0.738 | Acc: 73.720% (36860/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 4s779ms | Loss: 0.771 | Acc: 73.100% (7310/10000) 100/100
# Saving..
#
# Epoch: 130
#  [================================================================>]  Step: 23ms | Tot: 30s876ms | Loss: 0.733 | Acc: 74.220% (37110/50000) 391/391
#  [================================================================>]  Step: 36ms | Tot: 4s154ms | Loss: 0.772 | Acc: 73.290% (7329/10000) 100/100
# Saving..
#
# Epoch: 131
#  [================================================================>]  Step: 27ms | Tot: 30s968ms | Loss: 0.733 | Acc: 74.250% (37125/50000) 391/391
#  [================================================================>]  Step: 9ms | Tot: 5s378ms | Loss: 0.761 | Acc: 73.320% (7332/10000) 100/100
# Saving..
#
# Epoch: 132
#  [================================================================>]  Step: 32ms | Tot: 30s928ms | Loss: 0.721 | Acc: 74.648% (37324/50000) 391/391
#  [================================================================>]  Step: 25ms | Tot: 4s183ms | Loss: 0.767 | Acc: 73.750% (7375/10000) 100/100
# Saving..
#
# Epoch: 133
#  [================================================================>]  Step: 30ms | Tot: 30s906ms | Loss: 0.728 | Acc: 74.136% (37068/50000) 391/391
#  [================================================================>]  Step: 22ms | Tot: 4s207ms | Loss: 0.762 | Acc: 73.540% (7354/10000) 100/100
# Saving..
#
# Epoch: 134
#  [================================================================>]  Step: 28ms | Tot: 31s32ms | Loss: 0.729 | Acc: 74.314% (37157/50000) 391/391
#  [================================================================>]  Step: 26ms | Tot: 5s802ms | Loss: 0.766 | Acc: 73.410% (7341/10000) 100/100
# Saving..
#
# Epoch: 135
#  [================================================================>]  Step: 28ms | Tot: 31s56ms | Loss: 0.722 | Acc: 74.718% (37359/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 4s86ms | Loss: 0.763 | Acc: 73.760% (7376/10000) 100/100
# Saving..
#
# Epoch: 136
#  [================================================================>]  Step: 38ms | Tot: 30s973ms | Loss: 0.722 | Acc: 74.702% (37351/50000) 391/391
#  [================================================================>]  Step: 43ms | Tot: 4s236ms | Loss: 0.754 | Acc: 74.100% (7410/10000) 100/100
# Saving..
#
# Epoch: 137
#  [================================================================>]  Step: 28ms | Tot: 30s591ms | Loss: 0.724 | Acc: 74.612% (37306/50000) 391/391
#  [================================================================>]  Step: 48ms | Tot: 5s632ms | Loss: 0.754 | Acc: 73.800% (7380/10000) 100/100
# Saving..
#
# Epoch: 138
#  [================================================================>]  Step: 29ms | Tot: 30s463ms | Loss: 0.719 | Acc: 74.652% (37326/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 4s157ms | Loss: 0.749 | Acc: 73.990% (7399/10000) 100/100
# Saving..
#
# Epoch: 139
#  [================================================================>]  Step: 42ms | Tot: 30s775ms | Loss: 0.721 | Acc: 74.546% (37273/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 4s160ms | Loss: 0.751 | Acc: 74.030% (7403/10000) 100/100
# Saving..
#
# Epoch: 140
#  [================================================================>]  Step: 25ms | Tot: 30s907ms | Loss: 0.720 | Acc: 74.424% (37212/50000) 391/391
#  [================================================================>]  Step: 11ms | Tot: 5s679ms | Loss: 0.753 | Acc: 74.250% (7425/10000) 100/100
# Saving..
#
# Epoch: 141
#  [================================================================>]  Step: 28ms | Tot: 30s801ms | Loss: 0.718 | Acc: 74.632% (37316/50000) 391/391
#  [================================================================>]  Step: 28ms | Tot: 4s225ms | Loss: 0.748 | Acc: 74.230% (7423/10000) 100/100
# Saving..
#
# Epoch: 142
#  [================================================================>]  Step: 26ms | Tot: 31s6ms | Loss: 0.715 | Acc: 74.786% (37393/50000) 391/391
#  [================================================================>]  Step: 68ms | Tot: 4s242ms | Loss: 0.743 | Acc: 74.550% (7455/10000) 100/100
# Saving..
#
# Epoch: 143
#  [================================================================>]  Step: 32ms | Tot: 30s844ms | Loss: 0.710 | Acc: 75.008% (37504/50000) 391/391
#  [================================================================>]  Step: 34ms | Tot: 5s562ms | Loss: 0.750 | Acc: 73.980% (7398/10000) 100/100
# Saving..
#
# Epoch: 144
#  [================================================================>]  Step: 26ms | Tot: 30s721ms | Loss: 0.711 | Acc: 74.916% (37458/50000) 391/391
#  [================================================================>]  Step: 30ms | Tot: 4s159ms | Loss: 0.742 | Acc: 74.440% (7444/10000) 100/100
# Saving..
#
# Epoch: 145
#  [================================================================>]  Step: 29ms | Tot: 30s683ms | Loss: 0.709 | Acc: 74.954% (37477/50000) 391/391
#  [================================================================>]  Step: 18ms | Tot: 4s145ms | Loss: 0.745 | Acc: 74.470% (7447/10000) 100/100
# Saving..
#
# Epoch: 146
#  [================================================================>]  Step: 26ms | Tot: 30s507ms | Loss: 0.708 | Acc: 75.026% (37513/50000) 391/391
#  [================================================================>]  Step: 59ms | Tot: 5s700ms | Loss: 0.754 | Acc: 74.240% (7424/10000) 100/100
# Saving..
#
# Epoch: 147
#  [================================================================>]  Step: 26ms | Tot: 30s620ms | Loss: 0.708 | Acc: 75.176% (37588/50000) 391/391
#  [================================================================>]  Step: 32ms | Tot: 4s206ms | Loss: 0.743 | Acc: 74.420% (7442/10000) 100/100
# Saving..
#
# Epoch: 148
#  [================================================================>]  Step: 22ms | Tot: 30s429ms | Loss: 0.710 | Acc: 75.128% (37564/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 4s187ms | Loss: 0.737 | Acc: 74.880% (7488/10000) 100/100
# Saving..
#
# Epoch: 149
#  [================================================================>]  Step: 22ms | Tot: 30s464ms | Loss: 0.700 | Acc: 75.318% (37659/50000) 391/391
#  [================================================================>]  Step: 7ms | Tot: 5s174ms | Loss: 0.734 | Acc: 74.950% (7495/10000) 100/100
# Saving..
#
# Epoch: 150
#  [================================================================>]  Step: 28ms | Tot: 28s978ms | Loss: 0.700 | Acc: 75.428% (37714/50000) 391/391
#  [================================================================>]  Step: 21ms | Tot: 4s449ms | Loss: 0.734 | Acc: 74.500% (7450/10000) 100/100
# Saving..
#
# Epoch: 151
#  [================================================================>]  Step: 27ms | Tot: 29s703ms | Loss: 0.701 | Acc: 75.352% (37676/50000) 391/391
#  [================================================================>]  Step: 8ms | Tot: 3s966ms | Loss: 0.743 | Acc: 74.410% (7441/10000) 100/100
# Saving..
#
# Epoch: 152
#  [================================================================>]  Step: 28ms | Tot: 29s764ms | Loss: 0.696 | Acc: 75.388% (37694/50000) 391/391
#  [================================================================>]  Step: 24ms | Tot: 4s689ms | Loss: 0.738 | Acc: 74.650% (7465/10000) 100/100
# Saving..
#
# Epoch: 153
#  [================================================================>]  Step: 29ms | Tot: 30s341ms | Loss: 0.702 | Acc: 75.288% (37644/50000) 391/391
#  [================================================================>]  Step: 32ms | Tot: 5s386ms | Loss: 0.729 | Acc: 74.780% (7478/10000) 100/100
# Saving..
#
# Epoch: 154
#  [================================================================>]  Step: 35ms | Tot: 30s764ms | Loss: 0.695 | Acc: 75.638% (37819/50000) 391/391
#  [================================================================>]  Step: 33ms | Tot: 4s167ms | Loss: 0.735 | Acc: 74.570% (7457/10000) 100/100
# Saving..
#
# Epoch: 155
#  [================================================================>]  Step: 31ms | Tot: 30s750ms | Loss: 0.689 | Acc: 75.560% (37780/50000) 391/391
#  [================================================================>]  Step: 35ms | Tot: 4s266ms | Loss: 0.734 | Acc: 75.000% (7500/10000) 100/100
# Saving..
#
# Epoch: 156
#  [================================================================>]  Step: 31ms | Tot: 30s869ms | Loss: 0.694 | Acc: 75.390% (37695/50000) 391/391
#  [================================================================>]  Step: 12ms | Tot: 5s501ms | Loss: 0.739 | Acc: 74.670% (7467/10000) 100/100
# Saving..
#
# Epoch: 157
#  [================================================================>]  Step: 27ms | Tot: 30s938ms | Loss: 0.692 | Acc: 75.602% (37801/50000) 391/391
#  [================================================================>]  Step: 20ms | Tot: 4s64ms | Loss: 0.724 | Acc: 75.070% (7507/10000) 100/100
# Saving..
#
# Epoch: 158
#  [================================================================>]  Step: 25ms | Tot: 30s741ms | Loss: 0.694 | Acc: 75.564% (37782/50000) 391/391
#  [================================================================>]  Step: 23ms | Tot: 4s152ms | Loss: 0.730 | Acc: 74.750% (7475/10000) 100/100
# Saving..
#
# Epoch: 159
#  [================================================================>]  Step: 29ms | Tot: 30s954ms | Loss: 0.693 | Acc: 75.672% (37836/50000) 391/391
#  [================================================================>]  Step: 30ms | Tot: 5s497ms | Loss: 0.737 | Acc: 74.880% (7488/10000) 100/100
# Saving..
#
# Epoch: 160
#  [================================================================>]  Step: 63ms | Tot: 30s621ms | Loss: 0.686 | Acc: 75.968% (37984/50000) 391/391
#  [================================================================>]  Step: 11ms | Tot: 4s268ms | Loss: 0.736 | Acc: 74.740% (7474/10000) 100/100
# Saving..
#
# Epoch: 161
#  [================================================================>]  Step: 29ms | Tot: 30s580ms | Loss: 0.690 | Acc: 75.798% (37899/50000) 391/391
#  [================================================================>]  Step: 31ms | Tot: 4s165ms | Loss: 0.735 | Acc: 74.930% (7493/10000) 100/100
# Saving..
#
# Epoch: 162
#  [================================================================>]  Step: 24ms | Tot: 30s789ms | Loss: 0.685 | Acc: 75.640% (37820/50000) 391/391
#  [================================================================>]  Step: 24ms | Tot: 5s458ms | Loss: 0.726 | Acc: 75.380% (7538/10000) 100/100
# Saving..
#
# Epoch: 163
#  [================================================================>]  Step: 28ms | Tot: 30s548ms | Loss: 0.684 | Acc: 75.972% (37986/50000) 391/391
#  [================================================================>]  Step: 52ms | Tot: 4s136ms | Loss: 0.727 | Acc: 75.150% (7515/10000) 100/100
# Saving..
#
# Epoch: 164
#  [================================================================>]  Step: 27ms | Tot: 30s553ms | Loss: 0.686 | Acc: 75.634% (37817/50000) 391/391
#  [================================================================>]  Step: 23ms | Tot: 4s230ms | Loss: 0.737 | Acc: 74.680% (7468/10000) 100/100
# Saving..
#
# Epoch: 165
#  [================================================================>]  Step: 36ms | Tot: 30s848ms | Loss: 0.682 | Acc: 75.880% (37940/50000) 391/391
#  [================================================================>]  Step: 46ms | Tot: 5s350ms | Loss: 0.722 | Acc: 75.380% (7538/10000) 100/100
# Saving..
#
# Epoch: 166
#  [================================================================>]  Step: 41ms | Tot: 30s938ms | Loss: 0.679 | Acc: 76.082% (38041/50000) 391/391
#  [================================================================>]  Step: 28ms | Tot: 4s268ms | Loss: 0.726 | Acc: 74.920% (7492/10000) 100/100
# Saving..
#
# Epoch: 167
#  [================================================================>]  Step: 27ms | Tot: 30s937ms | Loss: 0.676 | Acc: 76.110% (38055/50000) 391/391
#  [================================================================>]  Step: 31ms | Tot: 4s221ms | Loss: 0.725 | Acc: 75.610% (7561/10000) 100/100
# Saving..
#
# Epoch: 168
#  [================================================================>]  Step: 29ms | Tot: 30s828ms | Loss: 0.675 | Acc: 76.118% (38059/50000) 391/391
#  [================================================================>]  Step: 15ms | Tot: 5s188ms | Loss: 0.721 | Acc: 75.500% (7550/10000) 100/100
# Saving..
#
# Epoch: 169
#  [================================================================>]  Step: 36ms | Tot: 30s686ms | Loss: 0.675 | Acc: 76.150% (38075/50000) 391/391
#  [================================================================>]  Step: 22ms | Tot: 4s850ms | Loss: 0.715 | Acc: 75.450% (7545/10000) 100/100
# Saving..
#
# Epoch: 170
#  [================================================================>]  Step: 23ms | Tot: 30s730ms | Loss: 0.674 | Acc: 76.356% (38178/50000) 391/391
#  [================================================================>]  Step: 15ms | Tot: 4s177ms | Loss: 0.716 | Acc: 75.530% (7553/10000) 100/100
# Saving..
#
# Epoch: 171
#  [================================================================>]  Step: 33ms | Tot: 30s765ms | Loss: 0.674 | Acc: 76.358% (38179/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 4s719ms | Loss: 0.723 | Acc: 75.410% (7541/10000) 100/100
# Saving..
#
# Epoch: 172
#  [================================================================>]  Step: 40ms | Tot: 30s322ms | Loss: 0.672 | Acc: 76.262% (38131/50000) 391/391
#  [================================================================>]  Step: 32ms | Tot: 5s217ms | Loss: 0.720 | Acc: 75.000% (7500/10000) 100/100
# Saving..
#
# Epoch: 173
#  [================================================================>]  Step: 28ms | Tot: 30s741ms | Loss: 0.668 | Acc: 76.560% (38280/50000) 391/391
#  [================================================================>]  Step: 8ms | Tot: 4s177ms | Loss: 0.719 | Acc: 75.460% (7546/10000) 100/100
# Saving..
#
# Epoch: 174
#  [================================================================>]  Step: 28ms | Tot: 30s640ms | Loss: 0.670 | Acc: 76.212% (38106/50000) 391/391
#  [================================================================>]  Step: 28ms | Tot: 4s140ms | Loss: 0.720 | Acc: 75.310% (7531/10000) 100/100
# Saving..
#
# Epoch: 175
#  [================================================================>]  Step: 18ms | Tot: 30s800ms | Loss: 0.671 | Acc: 76.378% (38189/50000) 391/391
#  [================================================================>]  Step: 45ms | Tot: 5s673ms | Loss: 0.730 | Acc: 74.940% (7494/10000) 100/100
# Saving..
#
# Epoch: 176
#  [================================================================>]  Step: 32ms | Tot: 30s539ms | Loss: 0.668 | Acc: 76.462% (38231/50000) 391/391
#  [================================================================>]  Step: 29ms | Tot: 4s278ms | Loss: 0.718 | Acc: 75.640% (7564/10000) 100/100
# Saving..
#
# Epoch: 177
#  [================================================================>]  Step: 33ms | Tot: 30s907ms | Loss: 0.663 | Acc: 76.644% (38322/50000) 391/391
#  [================================================================>]  Step: 17ms | Tot: 4s148ms | Loss: 0.718 | Acc: 75.370% (7537/10000) 100/100
# Saving..
#
# Epoch: 178
#  [================================================================>]  Step: 75ms | Tot: 32s465ms | Loss: 0.674 | Acc: 75.952% (37976/50000) 391/391
#  [================================================================>]  Step: 49ms | Tot: 5s628ms | Loss: 0.712 | Acc: 75.650% (7565/10000) 100/100
# Saving..
#
# Epoch: 179
#  [================================================================>]  Step: 26ms | Tot: 33s460ms | Loss: 0.663 | Acc: 76.750% (38375/50000) 391/391
#  [================================================================>]  Step: 17ms | Tot: 4s520ms | Loss: 0.715 | Acc: 75.750% (7575/10000) 100/100
# Saving..
#
# Epoch: 180
#  [================================================================>]  Step: 22ms | Tot: 33s37ms | Loss: 0.665 | Acc: 76.472% (38236/50000) 391/391
#  [================================================================>]  Step: 32ms | Tot: 4s726ms | Loss: 0.718 | Acc: 75.650% (7565/10000) 100/100
# Saving..
#
# Epoch: 181
#  [================================================================>]  Step: 24ms | Tot: 32s146ms | Loss: 0.659 | Acc: 77.026% (38513/50000) 391/391
#  [================================================================>]  Step: 31ms | Tot: 5s135ms | Loss: 0.720 | Acc: 75.070% (7507/10000) 100/100
# Saving..
#
# Epoch: 182
#  [================================================================>]  Step: 29ms | Tot: 33s146ms | Loss: 0.660 | Acc: 76.798% (38399/50000) 391/391
#  [================================================================>]  Step: 33ms | Tot: 4s402ms | Loss: 0.728 | Acc: 75.220% (7522/10000) 100/100
# Saving..
#
# Epoch: 183
#  [================================================================>]  Step: 26ms | Tot: 32s308ms | Loss: 0.658 | Acc: 76.624% (38312/50000) 391/391
#  [================================================================>]  Step: 21ms | Tot: 4s588ms | Loss: 0.720 | Acc: 75.170% (7517/10000) 100/100
# Saving..
#
# Epoch: 184
#  [================================================================>]  Step: 62ms | Tot: 32s479ms | Loss: 0.658 | Acc: 76.866% (38433/50000) 391/391
#  [================================================================>]  Step: 16ms | Tot: 5s19ms | Loss: 0.710 | Acc: 75.660% (7566/10000) 100/100
# Saving..
#
# Epoch: 185
#  [================================================================>]  Step: 26ms | Tot: 32s491ms | Loss: 0.658 | Acc: 76.902% (38451/50000) 391/391
#  [================================================================>]  Step: 35ms | Tot: 4s319ms | Loss: 0.721 | Acc: 75.390% (7539/10000) 100/100
# Saving..
#
# Epoch: 186
#  [================================================================>]  Step: 37ms | Tot: 33s276ms | Loss: 0.656 | Acc: 76.700% (38350/50000) 391/391
#  [================================================================>]  Step: 10ms | Tot: 5s329ms | Loss: 0.712 | Acc: 75.700% (7570/10000) 100/100
# Saving..
#
# Epoch: 187
#  [================================================================>]  Step: 32ms | Tot: 32s280ms | Loss: 0.653 | Acc: 77.116% (38558/50000) 391/391
#  [================================================================>]  Step: 35ms | Tot: 4s792ms | Loss: 0.708 | Acc: 75.790% (7579/10000) 100/100
# Saving..
#
# Epoch: 188
#  [================================================================>]  Step: 34ms | Tot: 32s86ms | Loss: 0.656 | Acc: 76.750% (38375/50000) 391/391
#  [================================================================>]  Step: 19ms | Tot: 4s286ms | Loss: 0.717 | Acc: 75.800% (7580/10000) 100/100
# Saving..
#
# Epoch: 189
#  [================================================================>]  Step: 29ms | Tot: 32s726ms | Loss: 0.652 | Acc: 76.852% (38426/50000) 391/391
#  [================================================================>]  Step: 53ms | Tot: 5s448ms | Loss: 0.710 | Acc: 75.770% (7577/10000) 100/100
# Saving..
#
# Epoch: 190
#  [================================================================>]  Step: 31ms | Tot: 31s813ms | Loss: 0.650 | Acc: 77.392% (38696/50000) 391/391
#  [================================================================>]  Step: 21ms | Tot: 5s266ms | Loss: 0.709 | Acc: 75.630% (7563/10000) 100/100
# Saving..
#
# Epoch: 191
#  [================================================================>]  Step: 34ms | Tot: 32s853ms | Loss: 0.649 | Acc: 77.186% (38593/50000) 391/391
#  [================================================================>]  Step: 39ms | Tot: 4s322ms | Loss: 0.711 | Acc: 75.850% (7585/10000) 100/100
# Saving..
#
# Epoch: 192
#  [================================================================>]  Step: 34ms | Tot: 32s406ms | Loss: 0.650 | Acc: 77.110% (38555/50000) 391/391
#  [================================================================>]  Step: 20ms | Tot: 5s391ms | Loss: 0.713 | Acc: 75.670% (7567/10000) 100/100
# Saving..
#
# Epoch: 193
#  [================================================================>]  Step: 55ms | Tot: 31s317ms | Loss: 0.649 | Acc: 77.072% (38536/50000) 391/391
#  [================================================================>]  Step: 29ms | Tot: 4s930ms | Loss: 0.707 | Acc: 75.880% (7588/10000) 100/100
# Saving..
#
# Epoch: 194
#  [================================================================>]  Step: 27ms | Tot: 30s997ms | Loss: 0.653 | Acc: 76.938% (38469/50000) 391/391
#  [================================================================>]  Step: 34ms | Tot: 4s169ms | Loss: 0.701 | Acc: 76.100% (7610/10000) 100/100
# Saving..
#
# Epoch: 195
#  [================================================================>]  Step: 31ms | Tot: 31s165ms | Loss: 0.648 | Acc: 77.156% (38578/50000) 391/391
#  [================================================================>]  Step: 55ms | Tot: 4s882ms | Loss: 0.707 | Acc: 75.800% (7580/10000) 100/100
# Saving..
#
# Epoch: 196
#  [================================================================>]  Step: 37ms | Tot: 30s490ms | Loss: 0.646 | Acc: 77.214% (38607/50000) 391/391
#  [================================================================>]  Step: 24ms | Tot: 5s693ms | Loss: 0.709 | Acc: 76.170% (7617/10000) 100/100
# Saving..
#
# Epoch: 197
#  [================================================================>]  Step: 29ms | Tot: 31s283ms | Loss: 0.645 | Acc: 77.330% (38665/50000) 391/391
#  [================================================================>]  Step: 17ms | Tot: 4s211ms | Loss: 0.701 | Acc: 75.800% (7580/10000) 100/100
# Saving..
#
# Epoch: 198
#  [================================================================>]  Step: 27ms | Tot: 30s949ms | Loss: 0.643 | Acc: 77.228% (38614/50000) 391/391
#  [================================================================>]  Step: 20ms | Tot: 4s354ms | Loss: 0.694 | Acc: 76.340% (7634/10000) 100/100
# Saving..
#
# Epoch: 199

# %%
checkpoint_path = os.path.join(main_path, 'checkpoint/ckpt.pth')

# 모델 상태 로드
checkpoint = torch.load(checkpoint_path)
net.load_state_dict(checkpoint['net'])
my_acc = checkpoint['acc']
my_epoch = checkpoint['epoch']

for k in range(my_epoch + 1, my_epoch + 1000):#101->1000
        train(k)
        test(k)
        if arg_optimizer=='sgd':
            scheduler.step()

        torch.save({
          'train_loss_history': train_loss_history,
          'train_accuracy_history': train_accuracy_history,
          'test_loss_history': test_loss_history,
          'test_accuracy_history': test_accuracy_history,
        }, os.path.join(main_path,f'history_{k}.pth'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5acf8903d33c> in <cell line: 1>()
# ----> 1 checkpoint_path = os.path.join(main_path, 'checkpoint/ckpt.pth')
#       2
#       3 # 모델 상태 로드
#       4 checkpoint = torch.load(checkpoint_path)
#       5 net.load_state_dict(checkpoint['net'])
#
# NameError: name 'os' is not defined
